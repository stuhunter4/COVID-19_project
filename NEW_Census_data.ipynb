# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
from api_keys import census_key

# %%
c = Census(census_key, year=2018)
LA_census_data = c.acs5.get(("NAME", "B01003_001E", "B01003_001E", "B01002_001E", "B19301_001E",
                             "B17001_002E"), {"for": "county:037", "in": "state:06"})
OC_census_data = c.acs5.get(("NAME", "B01003_001E", "B01003_001E", "B01002_001E", "B19301_001E",
                             "B17001_002E"), {"for": "county:059", "in": "state:06"})

MA_census_data = c.acs5.get(("NAME", "B01003_001E", "B01003_001E", "B01002_001E", "B19301_001E",
                             "B17001_002E"), {"for": "county:041", "in": "state:06"})
AL_census_data = c.acs5.get(("NAME", "B01003_001E", "B01003_001E", "B01002_001E", "B19301_001E",
                             "B17001_002E"), {"for": "county:001", "in": "state:06"})
CC_census_data = c.acs5.get(("NAME", "B01003_001E", "B01003_001E", "B01002_001E", "B19301_001E",
                             "B17001_002E"), {"for": "county:013", "in": "state:06"})
SM_census_data = c.acs5.get(("NAME", "B01003_001E", "B01003_001E", "B01002_001E", "B19301_001E",
                             "B17001_002E"), {"for": "county:081", "in": "state:06"})
SF_census_data = c.acs5.get(("NAME", "B01003_001E", "B01003_001E", "B01002_001E", "B19301_001E",
                             "B17001_002E"), {"for": "county:075", "in": "state:06"})

#convert to dataframe & rename/reorder columns
LA_census_df = pd.DataFrame(LA_census_data)
LA_census_df = LA_census_df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name"})
OC_census_df = pd.DataFrame(OC_census_data)
OC_census_df = OC_census_df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name"})

SF_census_df = pd.DataFrame(SF_census_data)
SF_census_df = SF_census_df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name"})
MA_census_df = pd.DataFrame(MA_census_data)
MA_census_df = MA_census_df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name"})
AL_census_df = pd.DataFrame(AL_census_data)
AL_census_df = AL_census_df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name"})
CC_census_df = pd.DataFrame(CC_census_data)
CC_census_df = CC_census_df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name"})
SM_census_df = pd.DataFrame(SM_census_data)
SM_census_df = SM_census_df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name"})

# %%
#add in Poverty Rate column (Poverty Count / Population)
LA_census_df["Poverty Rate"] = 100 * \
    LA_census_df["Poverty Count"].astype(
        int) / LA_census_df["Population"].astype(int)
OC_census_df["Poverty Rate"] = 100 * \
    OC_census_df["Poverty Count"].astype(
        int) / OC_census_df["Population"].astype(int)

SF_census_df["Poverty Rate"] = 100 * \
    SF_census_df["Poverty Count"].astype(
        int) / SF_census_df["Population"].astype(int)
MA_census_df["Poverty Rate"] = 100 * \
    MA_census_df["Poverty Count"].astype(
        int) / MA_census_df["Population"].astype(int)
AL_census_df["Poverty Rate"] = 100 * \
    AL_census_df["Poverty Count"].astype(
        int) / AL_census_df["Population"].astype(int)
CC_census_df["Poverty Rate"] = 100 * \
    CC_census_df["Poverty Count"].astype(
        int) / CC_census_df["Population"].astype(int)
SM_census_df["Poverty Rate"] = 100 * \
    SM_census_df["Poverty Count"].astype(
        int) / SM_census_df["Population"].astype(int)

# %%
#combine into new dataframe using concat
frames = [LA_census_df, OC_census_df, SF_census_df, MA_census_df,
          AL_census_df, CC_census_df, SM_census_df]
counties_census_df = pd.concat(frames)
counties_census_df
# Out:
#                                Name  Population  Median Age  \
# 0    Los Angeles County, California  10098052.0        36.2
# 0         Orange County, California   3164182.0        37.8
# 0  San Francisco County, California    870044.0        38.2
# 0          Marin County, California    260295.0        46.5
# 0        Alameda County, California   1643700.0        37.4
# 0   Contra Costa County, California   1133247.0        39.4
# 0      San Mateo County, California    765935.0        39.6
#
#    Per Capita Income  Poverty Count state county  Poverty Rate
# 0            32469.0      1589956.0    06    037     15.745175
# 0            39590.0       359503.0    06    059     11.361641
# 0            64157.0        92979.0    06    075     10.686701
# 0            69275.0        19341.0    06    041      7.430415
# 0            44283.0       170884.0    06    001     10.396301
# 0            45524.0       102543.0    06    013      9.048601
# ...

# %%
#read in csv file "Count_size" for total area numbers
county_size = pd.read_csv("Resources/NEW_County_size.csv")
#place elements from Total Area column into new series
total_area = county_size["Total Area"]

#reset index on counties_census_df so the index and series match
counties_census_df = counties_census_df.reset_index(drop=True)

#add new series to a new column in orginal df
counties_census_df["Total Area (square mi.)"] = total_area

#calculate population density and place in new column
counties_census_df["Population Density"] = counties_census_df["Population"] / counties_census_df["Total Area (square mi.)"]
counties_census_df
# Out:
#                                Name  Population  Median Age  \
# 0    Los Angeles County, California  10098052.0        36.2
# 1         Orange County, California   3164182.0        37.8
# 2  San Francisco County, California    870044.0        38.2
# 3          Marin County, California    260295.0        46.5
# 4        Alameda County, California   1643700.0        37.4
# 5   Contra Costa County, California   1133247.0        39.4
# 6      San Mateo County, California    765935.0        39.6
#
#    Per Capita Income  Poverty Count state county  Poverty Rate  \
# 0            32469.0      1589956.0    06    037     15.745175
# 1            39590.0       359503.0    06    059     11.361641
# 2            64157.0        92979.0    06    075     10.686701
# 3            69275.0        19341.0    06    041      7.430415
# 4            44283.0       170884.0    06    001     10.396301
# 5            45524.0       102543.0    06    013      9.048601
# ...

# %%
#reorder columns
counties_census_df = counties_census_df[["Name", "Population", "Population Density",
                                         "Median Age", "Per Capita Income", "Poverty Count",
                                         "Poverty Rate", "Total Area (square mi.)"]]
counties_census_df
# Out:
#                                Name  Population  Population Density  \
# 0    Los Angeles County, California  10098052.0        12298.888989
# 1         Orange County, California   3164182.0         3935.241393
# 2  San Francisco County, California    870044.0          183.123902
# 3          Marin County, California    260295.0          314.293442
# 4        Alameda County, California   1643700.0         1733.866246
# 5   Contra Costa County, California   1133247.0         4887.002458
# 6      San Mateo County, California    765935.0         1033.710458
#
#    Median Age  Per Capita Income  Poverty Count  Poverty Rate  \
# 0        36.2            32469.0      1589956.0     15.745175
# 1        37.8            39590.0       359503.0     11.361641
# 2        38.2            64157.0        92979.0     10.686701
# 3        46.5            69275.0        19341.0      7.430415
# 4        37.4            44283.0       170884.0     10.396301
# ...

# %%
#export as csv for use elsewhere
counties_census_df.to_csv("Resources/NEW_LASF_Census2018.csv", index=False, header=True)
